# %%
import pandas as pd

# %%
d = {'miles_per_week': [37,39,46,51,88,17,18,20,21,22,23,24,25,27,28,29,30,31,32,33,34,38,40,42,57,68,35,36,41,43,45,47,49,50,52,53,54,55,56,58,59,60,61,63,64,65,66,69,70,72,73,75,76,77,78,80,81,82,83,84,85,86,87,89,91,92,93,95,96,97,98,99,100,101,102,103,104,105,106,107,109,110,111,113,114,115,116,116,118,119,120,121,123,124,126,62,67,74,79,90,112],
'completed_50m_ultra': ['no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','no','yes','yes','yes','yes','no','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','no','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes','yes',]}

# %%
df = pd.DataFrame(data=d)

# %%
df.head()
# Out:
#    miles_per_week completed_50m_ultra
# 0              37                  no
# 1              39                  no
# 2              46                  no
# 3              51                  no
# 4              88                  no

# %%
df.head()
# Out:
#    miles_per_week  completed_50m_ultra
# 0              37                  1.0
# 1              39                  1.0
# 2              46                  1.0
# 3              51                  1.0
# 4              88                  1.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['miles_per_week'].plot(kind='hist', bins=20, title='miles_per_week')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['miles_per_week']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'miles_per_week'}, axis=1)
#               .sort_values('miles_per_week', ascending=True))
#   xs = counted['miles_per_week']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_1.sort_values('miles_per_week', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('miles_per_week')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['completed_50m_ultra']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'completed_50m_ultra'}, axis=1)
#               .sort_values('completed_50m_ultra', ascending=True))
#   xs = counted['completed_50m_ultra']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_2.sort_values('completed_50m_ultra', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('completed_50m_ultra')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3['miles_per_week'].plot(kind='line', figsize=(8, 4), title='miles_per_week')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5['miles_per_week'].plot(kind='hist', bins=20, title='miles_per_week')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='index', y='miles_per_week', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_7.sort_values('index', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('index')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['miles_per_week']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'miles_per_week'}, axis=1)
#               .sort_values('miles_per_week', ascending=True))
#   xs = counted['miles_per_week']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('miles_per_week', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('miles_per_week')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['completed_50m_ultra']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'completed_50m_ultra'}, axis=1)
#               .sort_values('completed_50m_ultra', ascending=True))
#   xs = counted['completed_50m_ultra']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('completed_50m_ultra', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('completed_50m_ultra')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_10['index'].plot(kind='line', figsize=(8, 4), title='index')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['miles_per_week'].plot(kind='line', figsize=(8, 4), title='miles_per_week')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder

# %%
finisfed_race = ['yes','no']

# %%
enc = OrdinalEncoder(categories=[finisfed_race])

# %%
df['completed_50m_ultra'] = enc.fit_transform(df[['completed_50m_ultra']])

# %%
df.head()
# Out:
#    miles_per_week  completed_50m_ultra
# 0              37                  1.0
# 1              39                  1.0
# 2              46                  1.0
# 3              51                  1.0
# 4              88                  1.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['miles_per_week'].plot(kind='hist', bins=20, title='miles_per_week')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['miles_per_week']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'miles_per_week'}, axis=1)
#               .sort_values('miles_per_week', ascending=True))
#   xs = counted['miles_per_week']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_13.sort_values('miles_per_week', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('miles_per_week')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['completed_50m_ultra']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'completed_50m_ultra'}, axis=1)
#               .sort_values('completed_50m_ultra', ascending=True))
#   xs = counted['completed_50m_ultra']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_14.sort_values('completed_50m_ultra', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('completed_50m_ultra')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_15['miles_per_week'].plot(kind='line', figsize=(8, 4), title='miles_per_week')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
import matplotlib.pyplot as plt
plt.scatter(df['miles_per_week'],df['completed_50m_ultra'])

# %%
sns.countplot(x='completed_50m_ultra',data=df)
# Out:
# <Axes: xlabel='completed_50m_ultra', ylabel='count'>

# %%
x = df.iloc[:,:1]
y = df.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.8,random_state=11)

# %%
x_train.shape
# Out:
# (20, 1)

# %%
x_test.shape
# Out:
# (81, 1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_test,y_test)
# Out:
# 0.8148148148148148

# %%
from sklearn.metrics import confusion_matrix

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[45 11]
#  [ 4 21]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.80      0.86        56
#          1.0       0.66      0.84      0.74        25
#
#     accuracy                           0.81        81
#    macro avg       0.79      0.82      0.80        81
# weighted avg       0.84      0.81      0.82        81
